# %%
import pandas as pd
df=pd.read_excel("/content/mega_data_cleaning_dataset (1).xlsx")

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.drop_duplicates(subset='Customer_ID')
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
df.drop_duplicates(subset='Email',keep='first')
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121               NaN  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df['Name'].fillna(value='unknown',inplace=True)
df
# Out:
# /tmp/ipython-input-2900861196.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Name'].fillna(value='unknown',inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# ...

# %%
df['Email'].fillna(value='noemail@example.com',inplace=True)
df
# Out:
# /tmp/ipython-input-265938009.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Email'].fillna(value='noemail@example.com',inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# ...

# %%
df['Product_Name'].fillna(value='misc',inplace=True)
df
# Out:
# /tmp/ipython-input-2215971817.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Product_Name'].fillna(value='misc',inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# ...

# %%
df['Category'].fillna(value='misc',inplace=True)
df
# Out:
# /tmp/ipython-input-1836837431.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Category'].fillna(value='misc',inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# ...

# %%
x=df['Feedback_Score'].median()
df['Feedback_Score'].fillna(value=x,inplace=True)
df
# Out:
# /tmp/ipython-input-2399860531.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Feedback_Score'].fillna(value=x,inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# ...

# %%
df['Quantity'].fillna(value='1',inplace=True)
df
# Out:
# /tmp/ipython-input-2030626627.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Quantity'].fillna(value='1',inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID            0
# Name                   0
# Age                    0
# Gender                 0
# Country              481
# State               1049
# City                   0
# Email                  0
# Signup_Date            0
# Account_Status      2483
# Product_ID             0
# Product_Name           0
# Category               0
# Price                  0
# Discount             973
# Quantity               0
# Purchase_Date          0
# Delivery_Date          0
# Payment_Type           0
# Feedback_Score         0
# Comments            1953
# Customer_Loyalty    2539
# Last_Login           983
# Signup_Channel         0
# Total_Purchase         0
# dtype: int64

# %%
df[df['Price'] >= 0]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Price']==0]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Quantity']>=0]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[(df['Age'] < 0) | (df['Age'] > 120)]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[(df['Feedback_Score'] < 1) | (df['Feedback_Score'] > 5)]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Delivery_Date'] >= df['Purchase_Date']]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
df['Gender'].replace({'Mle':'Male','f':'Female'},inplace=True)
df
# Out:
# /tmp/ipython-input-362904268.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Mle':'Male','f':'Female'},inplace=True)
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# ...

# %%
df['Payment_Type'] = df['Payment_Type'].str.strip().str.title()
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110    Male              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11    Male               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male                  Albania
#
#              State                City                               Email  \
# ...

# %%
df['Account_Status'] = df['Account_Status'].str.strip().str.title()
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110    Male              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11    Male               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', na=False)]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110    Male              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11    Male               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Price'] > 500]
df['Price']
# Out:
# 0       616.19
# 1       564.80
# 2       224.76
# 3       817.93
# 4       937.30
#          ...
# 9995    161.31
# 9996    158.53
# 9997    -34.54
# 9998    192.82
# 9999    372.37
# Name: Price, Length: 10000, dtype: float64

# %%
df[df['Feedback_Score'] < 3]
df['Feedback_Score']
# Out:
# 0       4.7
# 1       4.2
# 2       3.7
# 3       4.4
# 4       2.5
#        ...
# 9995    1.2
# 9996    3.7
# 9997    4.6
# 9998    0.3
# 9999    0.9
# Name: Feedback_Score, Length: 10000, dtype: float64

# %%
df[(df['Customer_Loyalty'] == 'VIP') & (df['Total_Purchase'] > 1000)]
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110    Male              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11    Male               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male                  Albania
#
#              State                City                               Email  \
# ...

# %%
df[df['Account_Status'] == 'Banned']
df['Account_Status']
# Out:
# 0       Inactive
# 1            NaN
# 2         Active
# 3         Active
# 4            NaN
#           ...
# 9995    Inactive
# 9996         NaN
# 9997      Banned
# 9998    Inactive
# 9999    Inactive
# Name: Account_Status, Length: 10000, dtype: object

# %%
df[(df['Delivery_Date'] - df['Purchase_Date']).dt.days > 7]
df['Delivery_Date']
# Out:
# 0      2025-09-10
# 1      2025-05-29
# 2      2025-01-30
# 3      2025-01-24
# 4      2025-04-26
#           ...
# 9995   2025-03-19
# 9996   2025-04-12
# 9997   2025-08-14
# 9998   2025-03-21
# 9999   2025-07-01
# Name: Delivery_Date, Length: 10000, dtype: datetime64[ns]

# %%
df[df['Category'] == 'Electronics']
df['Category']
# Out:
# 0              misc
# 1          Clothing
# 2              Misc
# 3              misc
# 4       Electronics
#            ...
# 9995           Misc
# 9996           misc
# 9997           misc
# 9998           misc
# 9999           misc
# Name: Category, Length: 10000, dtype: object

# %%
df[df['Country'] == 'India']
df['Country']
# Out:
# 0                           NaN
# 1                        Uganda
# 2                    Tajikistan
# 3                         Chile
# 4                   Timor-Leste
#                  ...
# 9995                 Cape Verde
# 9996                        NaN
# 9997    Cocos (Keeling) Islands
# 9998          Equatorial Guinea
# 9999                    Albania
# Name: Country, Length: 10000, dtype: object

# %%
df[df['Quantity'] > 10]
df['Quantity']
# Out:
# 0       12
# 1        9
# 2        0
# 3        9
# 4        7
#         ..
# 9995    17
# 9996    -5
# 9997     4
# 9998     8
# 9999    15
# Name: Quantity, Length: 10000, dtype: int64

# %%
high_discount = df[df['Discount'] > 50]
display(high_discount)
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Name, Age, Gender, Country, State, City, Email, Signup_Date, Account_Status, Product_ID, Product_Name, Category, Price, Discount, Quantity, Purchase_Date, Delivery_Date, Payment_Type, Feedback_Score, Comments, Customer_Loyalty, Last_Login, Signup_Channel, Total_Purchase]
# Index: []
#
# [0 rows x 25 columns]

# %%
large_total= df[df['Price'] * df['Quantity'] > 1000]
large_total
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110    Male        Timor-Leste
# 5            8213    Kristen Harvey   62   Other          Greenland
# ...           ...               ...  ...     ...                ...
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128  Female             Tuvalu
# 9995         8287    Deborah Garcia   11    Male         Cape Verde
# 9998         8121           unknown  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male            Albania
#
#           State                 City                               Email  \
# 0      Arkansas            Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
 df['Total_Purchase'] = df['Price'] * df['Quantity']
 df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105    Male               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110    Male              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11    Male               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121           unknown  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67    Male                  Albania
#
#              State                City                               Email  \
# ...

# %%
df['Discounted_Price'] = df['Price'] - df['Discount']
df['Discounted_Price']
# Out:
# 0       580.23
# 1       517.73
# 2          NaN
# 3       788.94
# 4       897.71
#          ...
# 9995    127.71
# 9996    139.42
# 9997    -52.25
# 9998    153.43
# 9999    370.25
# Name: Discounted_Price, Length: 10000, dtype: float64

# %%
df['Delivery_Duration'] = (df['Delivery_Date'] - df['Purchase_Date']).dt.days
df['Delivery_Duration']
# Out:
# 0       159
# 1       126
# 2      -190
# 3       -60
# 4        -8
#        ...
# 9995     48
# 9996    -40
# 9997    177
# 9998    -70
# 9999     85
# Name: Delivery_Duration, Length: 10000, dtype: int64

# %%
df['Age_Group'] = pd.cut(df['Age'], bins=[0,12,19,59,120], labels=['Child','Teen','Adult','Senior'])
df['Age_Group']
# Out:
# 0        Adult
# 1        Adult
# 2       Senior
# 3       Senior
# 4       Senior
#          ...
# 9995     Child
# 9996    Senior
# 9997       NaN
# 9998    Senior
# 9999    Senior
# Name: Age_Group, Length: 10000, dtype: category
# Categories (4, object): ['Child' < 'Teen' < 'Adult' < 'Senior']

# %%
df['Gender_Code'] = df['Gender'].map({'Male':1, 'Female':2, 'Other':3})
df['Gender_Code']
# Out:
# 0       3
# 1       1
# 2       1
# 3       2
# 4       1
#        ..
# 9995    1
# 9996    2
# 9997    3
# 9998    1
# 9999    1
# Name: Gender_Code, Length: 10000, dtype: int64

# %%
df['Account_Status_Code'] = df['Account_Status'].map({'Active':1, 'Inactive':0, 'Banned':-1})
df['Account_Status_Code']
# Out:
# 0       0.0
# 1       NaN
# 2       1.0
# 3       1.0
# 4       NaN
#        ...
# 9995    0.0
# 9996    NaN
# 9997   -1.0
# 9998    0.0
# 9999    0.0
# Name: Account_Status_Code, Length: 10000, dtype: float64

# %%
df['Country'] = df['Country'].str.title()
df['Country']
# Out:
# 0                           NaN
# 1                        Uganda
# 2                    Tajikistan
# 3                         Chile
# 4                   Timor-Leste
#                  ...
# 9995                 Cape Verde
# 9996                        NaN
# 9997    Cocos (Keeling) Islands
# 9998          Equatorial Guinea
# 9999                    Albania
# Name: Country, Length: 10000, dtype: object

# %%
df['Payment_Type'] = df['Payment_Type'].str.title()
df['Payment_Type']
# Out:
# 0           Up
# 1         Cash
# 2          Upi
# 3        Debit
# 4           Up
#          ...
# 9995      Cash
# 9996    Credit
# 9997       Upi
# 9998    Credit
# 9999      Cash
# Name: Payment_Type, Length: 10000, dtype: object

# %%
top_products = df.groupby('Product_Name')['Total_Purchase'].sum().head(5)
top_products
# Out:
# Product_Name
# American    23804.05
# Congress    37982.33
# Democrat    72579.39
# I           36947.17
# Mr          61450.29
# Name: Total_Purchase, dtype: float64

# %%
top_customers = df.groupby('Customer_ID')['Total_Purchase'].sum().head(5)
top_customers
# Out:
# Customer_ID
# 1    4714.19
# 2   -1857.22
# 3    5907.22
# 4    2144.52
# 8    7702.23
# Name: Total_Purchase, dtype: float64

# %%
avg_discount = df.groupby('Category')['Discount'].mean()
avg_discount
# Out:
# Category
# Clothing       19.256855
# Electronics    19.930981
# Misc           19.426081
# misc           20.103203
# Name: Discount, dtype: float64

# %%
avg_feedback_cat = df.groupby('Category')['Feedback_Score'].mean()
avg_feedback_cat
# Out:
# Category
# Clothing       3.022495
# Electronics    3.026078
# Misc           2.994045
# misc           2.974704
# Name: Feedback_Score, dtype: float64

# %%
popular_payment = df['Payment_Type'].mode()[0]
popular_payment
# Out:
# 'Upi'

# %%
highest_order = df.loc[(df['Price'] * df['Quantity']).idxmax()]
highest_order
# Out:
# Customer_ID                                         7924
# Name                                      Sydney Perkins
# Age                                                   44
# Gender                                            Female
# Country                                          Grenada
# State                                       North Dakota
# City                                           Ethanberg
# Email                  aguilarthomas@garcia-calderon.org
# Signup_Date                          2020-02-18 00:00:00
# Account_Status                                    Banned
# Product_ID                                            29
# Product_Name                                       staff
# Category                                     Electronics
# Price                                              996.0
# Discount                                             NaN
# Quantity                                              20
# ...

# %%
frequent_customers = df['Customer_ID'].value_counts()[df['Customer_ID'].value_counts() > 5]
frequent_customers
# Out:
# Customer_ID
# 8429    7
# 4367    6
# 7157    6
# 5841    6
# 5675    6
# Name: count, dtype: int64

# %%
sorted_delivery = df.sort_values('Delivery_Duration', ascending=False)
sorted_delivery
# Out:
#       Customer_ID               Name  Age  Gender  \
# 1364         8989        Kevin Walsh   61  Female
# 5839         4567   Mallory Martinez   48  Female
# 5095         2276  Annette Hernandez   37  Female
# 3972         2058    Rebecca Schmidt  109    Male
# 383          7338        Eric Strong   23    Male
# ...           ...                ...  ...     ...
# 6595         3219      David Sanchez   36   Other
# 2350         8909    Jacqueline Ross   26   Other
# 42           7532       Sandra Evans   10   Other
# 6354         3077       Sara Watkins   62    Male
# 6838          465            unknown   82  Female
#
#                                Country           State                  City  \
# 1364                           Burundi   Massachusetts          Lake Allison
# 5839                               NaN  North Carolina          Jonesborough
# 5095                         Venezuela           Maine       Port Collinberg
# ...

# %%
max_feedback = df.loc[df['Feedback_Score'].idxmax()]
max_feedback
# Out:
# Customer_ID                                                  7391
# Name                                                Alice Bentley
# Age                                                            90
# Gender                                                       Male
# Country                                                      Guam
# State                                                      Hawaii
# City                                             West Michaeltown
# Email                                         alawson@hotmail.com
# Signup_Date                                   2021-10-04 00:00:00
# Account_Status                                           Inactive
# Product_ID                                                    320
# Product_Name                                                 lead
# Category                                                     Misc
# Price                                                      270.44
# ...

# %%
min_feedback = df.loc[df['Feedback_Score'].idxmin()]
min_feedback
# Out:
# Customer_ID                                    5304
# Name                                 David Holloway
# Age                                              30
# Gender                                         Male
# Country                                   Nicaragua
# State                                       Montana
# City                                      Nancybury
# Email                  angelaanthony@carpenter.info
# Signup_Date                     2022-12-11 00:00:00
# Account_Status                               Banned
# Product_ID                                      206
# Product_Name                                   then
# Category                                       Misc
# Price                                         48.82
# Discount                                      21.57
# Quantity                                         20
# Purchase_Date                   2025-08-24 00:00:00
# Delivery_Date                   2025-05-19 00:00:00
# ...

# %%
grouped_purchase = df.groupby(['Country','Category'])['Total_Purchase'].sum().reset_index()
grouped_purchase
# Out:
#          Country     Category  Total_Purchase
# 0    Afghanistan     Clothing        10926.08
# 1    Afghanistan  Electronics        20519.32
# 2    Afghanistan         Misc        63391.79
# 3    Afghanistan         misc        52536.30
# 4        Albania     Clothing        48820.78
# ..           ...          ...             ...
# 967       Zambia         misc        37818.12
# 968     Zimbabwe     Clothing        44590.88
# 969     Zimbabwe  Electronics        60527.83
# 970     Zimbabwe         Misc        27229.12
# 971     Zimbabwe         misc        26756.68
#
# [972 rows x 3 columns]
